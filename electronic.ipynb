# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Train_e.csv")
dft=pd.read_csv("Test_e.csv")

# %%
df
# Out:
#       Brand                                         Model_Info  \
# 0         1                      name0 name234 64gb space grey
# 1         1   phone 7 name42 name453 new condition box acce...
# 2         1            name0 x 256gb leess used good condition
# 3         1                     name0 6s plus 64 gb space grey
# 4         1   phone 7 sealed pack brand new factory outet p...
# ...     ...                                                ...
# 2321      1       name87 name0 6 64gb accs bill nice condition
# 2322      0                               huawie name2719 lite
# 2323      1                                  name0 5s 16gb box
# 2324      1                    name0 7 32gb flawless condition
# 2325      1    name0 name414 max 64gb 10 months apple warranty
#
#                                  Additional_Description  Locality  City  \
# 0      1yesr old mobile number 999two905two99 bill c...       878     8
# ...

# %%
df["all"]=df["Model_Info"]+df["Additional_Description"]

# %%
gb2=[]
gb3=[]
gb4=[]
gb6=[]
gb8=[]
gb16=[]
gb64=[]
gb128=[]
gb256=[]
gb32=[]

# %%
for i in range(0,2326):
    if "64gb" in df["all"][i]:
        gb64.append(1)
        continue
    elif "64 gb" in df["all"][i]:
        gb64.append(1)
    else:
        gb64.append(0)
        
        
for i in range(0,2326):
    if "16gb" in df["all"][i]:
        gb16.append(1)
        continue
    elif "16 gb" in df["all"][i]:
        gb16.append(1)
    else:
        gb16.append(0)
        
        
        
        
for i in range(0,2326):
    if "256gb" in df["all"][i]:
        gb256.append(1)
        continue
    elif "256 gb" in df["all"][i]:
        gb256.append(1)
    else:
        gb256.append(0)
        
        
for i in range(0,2326):
    if "8gb" in df["all"][i]:
        gb8.append(1)
        continue
    elif "8 gb" in df["all"][i]:
        gb8.append(1)
    else:
        gb8.append(0)

        
        
        
        
for i in range(0,2326):
    if "4gb" in df["all"][i]:
        gb4.append(1)
        continue
    elif "4 gb" in df["all"][i]:
        gb4.append(1)
    else:
        gb4.append(0)
        
        
        
for i in range(0,2326):
    if "3gb" in df["all"][i]:
        gb3.append(1)
        continue
    elif "3 gb" in df["all"][i]:
        gb3.append(1)
    else:
        gb3.append(0)
        
for i in range(0,2326):
    if "2gb" in df["all"][i]:
        gb2.append(1)
        continue
    elif "2 gb" in df["all"][i]:
        gb2.append(1)
    else:
        gb2.append(0)
        
        
for i in range(0,2326):
    if "6gb" in df["all"][i]:
        gb6.append(1)
        continue
    elif "6 gb" in df["all"][i]:
        gb6.append(1)
    else:
        gb6.append(0)
        
        
for i in range(0,2326):
    if "128gb" in df["all"][i]:
        gb128.append(1)
        continue
    elif "128 gb" in df["all"][i]:
        gb128.append(1)
    else:
        gb128.append(0)

for i in range(0,2326):
    if "32gb" in df["all"][i]:
        gb32.append(1)
        continue
    elif "32 gb" in df["all"][i]:
        gb32.append(1)
    else:
        gb32.append(0)

# %%
df["gb2"]=gb2
df["gb3"]=gb3
df["gb4"]=gb4
df["gb6"]=gb6
df["gb8"]=gb8
df["gb16"]=gb16
df["gb64"]=gb64
df["gb32"]=gb32
df["gb128"]=gb128
df["gb256"]=gb256

# %%
dft["all"]=dft["Model_Info"]+dft["Additional_Description"]

# %%
gb2=[]
gb3=[]
gb4=[]
gb6=[]
gb8=[]
gb16=[]
gb64=[]
gb128=[]
gb256=[]
gb32=[]

# %%
for i in range(0,997):
    if "64gb" in dft["all"][i]:
        gb64.append(1)
        continue
    elif "64 gb" in dft["all"][i]:
        gb64.append(1)
    else:
        gb64.append(0)
        
        
for i in range(0,997):
    if "16gb" in dft["all"][i]:
        gb16.append(1)
        continue
    elif "16 gb" in dft["all"][i]:
        gb16.append(1)
    else:
        gb16.append(0)
        
        
        
        
for i in range(0,997):
    if "256gb" in dft["all"][i]:
        gb256.append(1)
        continue
    elif "256 gb" in dft["all"][i]:
        gb256.append(1)
    else:
        gb256.append(0)
        
for i in range(0,997):
    if "8gb" in dft["all"][i]:
        gb8.append(1)
        continue
    elif "8 gb" in dft["all"][i]:
        gb8.append(1)
    else:
        gb8.append(0)

        
        
        
        
for i in range(0,997):
    if "4gb" in dft["all"][i]:
        gb4.append(1)
        continue
    elif "4 gb" in dft["all"][i]:
        gb4.append(1)
    else:
        gb4.append(0)
        
        
        
for i in range(0,997):
    if "3gb" in dft["all"][i]:
        gb3.append(1)
        continue
    elif "3 gb" in dft["all"][i]:
        gb3.append(1)
    else:
        gb3.append(0)
        
for i in range(0,997):
    if "2gb" in dft["all"][i]:
        gb2.append(1)
        continue
    elif "2 gb" in dft["all"][i]:
        gb2.append(1)
    else:
        gb2.append(0)
        
for i in range(0,997):
    if "6gb" in dft["all"][i]:
        gb6.append(1)
        continue
    elif "6 gb" in dft["all"][i]:
        gb6.append(1)
    else:
        gb6.append(0)
        
        
for i in range(0,997):
    if "128gb" in dft["all"][i]:
        gb128.append(1)
        continue
    elif "128 gb" in dft["all"][i]:
        gb128.append(1)
    else:
        gb128.append(0)
        
for i in range(0,997):
    if "32gb" in dft["all"][i]:
        gb32.append(1)
        continue
    elif "32 gb" in dft["all"][i]:
        gb32.append(1)
    else:
        gb32.append(0)

# %%
dft["gb2"]=gb2
dft["gb3"]=gb3
dft["gb4"]=gb4
dft["gb6"]=gb6
dft["gb8"]=gb8
dft["gb16"]=gb16
dft["gb64"]=gb64
dft["gb32"]=gb32
dft["gb128"]=gb128
dft["gb256"]=gb256

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
corpus=[]
# Out:
# [nltk_data] Downloading package stopwords to /home/sumit/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
for i in range(0,2326):
    v=re.sub('[^a-zA-Z0-9]', ' ',df["all"][i])
    v=v.lower() 
    v=v.split()
    v=[word for word in v if not word in stopwords.words('english')]
    v=' '.join(v)
    corpus.append(v)

# %%
corpus
# Out:
# ['name0 name234 64gb space grey 1yesr old mobile number 999two905two99 bill charger',
#  'phone 7 name42 name453 new condition box accessories 101004800 1010065900 7000',
# ...

# %%
corpus2=[]
for i in range(0,997):
    v=re.sub('[^a-zA-Z0-9]', ' ',dft["all"][i])
    v=v.lower() 
    v=v.split()
    v=[word for word in v if not word in stopwords.words('english')]
    v=' '.join(v)
    corpus2.append(v)

# %%
df["ok"]=corpus
dft["ok"]=corpus2

# %%
final_df=pd.concat([df,dft],axis=0)

# %%
final_df.drop(["Additional_Description","Model_Info","all"],inplace=True,axis=1)

# %%
final_df
# Out:
#      Brand  City  Locality    Price  State  gb128  gb16  gb2  gb256  gb3  \
# 0        1     8       878  15000.0      2      0     0    0      0    0
# 1        1     4      1081  18800.0      0      0     0    0      0    0
# 2        1    11       495  50000.0      4      1     0    0      1    0
# 3        1    10       287  16500.0      7      0     0    0      1    0
# 4        1     4       342  26499.0      0      0     0    0      0    0
# ..     ...   ...       ...      ...    ...    ...   ...  ...    ...  ...
# 992      1     4       796      NaN      0      0     1    1      0    0
# 993      1    17       145      NaN      7      1     0    0      0    0
# 994      0    13       352      NaN      5      1     0    1      0    1
# 995      1     4       350      NaN      0      0     0    0      0    0
# 996      1    11       602      NaN      4      1     0    0      0    0
#
#      gb32  gb4  gb6  gb64  gb8  \
# 0       0    1    0     1    0
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
z=cv.fit_transform(final_df["ok"])

# %%
z
# Out:
# <3323x6933 sparse matrix of type '<class 'numpy.int64'>'
# 	with 69158 stored elements in Compressed Sparse Row format>

# %%
final_df.drop(["Price","ok"],inplace=True,axis=1)

# %%
final_df

# %%
m=final_df

# %%
m=m.values

# %%
from scipy.sparse import hstack

# %%
m=hstack((z,m))

# %%
m
# Out:
# <3323x6937 sparse matrix of type '<class 'numpy.int64'>'
# 	with 81606 stored elements in COOrdinate format>

# %%
from scipy.sparse import coo_matrix
m = coo_matrix(m)
m = m.tocsr()

# %%
x=m[:2326,:]
xt=m[2326:,:]

# %%
y=df.Price

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=0)

# %%
from catboost import CatBoostRegressor
f = CatBoostRegressor()
f.fit(x_train, y_train)
# Out:
# 0:	learn: 20987.8724819	total: 25.9ms	remaining: 25.9s
# 1:	learn: 20789.5135534	total: 40.4ms	remaining: 20.2s
# 2:	learn: 20575.3724421	total: 51ms	remaining: 16.9s
# 3:	learn: 20378.8123797	total: 59.9ms	remaining: 14.9s
# 4:	learn: 20192.4665970	total: 67.5ms	remaining: 13.4s
# 5:	learn: 19996.4819380	total: 74.6ms	remaining: 12.4s
# 6:	learn: 19805.8609140	total: 81.4ms	remaining: 11.6s
# 7:	learn: 19626.7036130	total: 88.2ms	remaining: 10.9s
# 8:	learn: 19472.6586263	total: 95.1ms	remaining: 10.5s
# 9:	learn: 19287.9548237	total: 102ms	remaining: 10.1s
# 10:	learn: 19130.6106089	total: 109ms	remaining: 9.77s
# 11:	learn: 18984.5004209	total: 115ms	remaining: 9.49s
# 12:	learn: 18853.8033458	total: 122ms	remaining: 9.26s
# 13:	learn: 18735.4750080	total: 129ms	remaining: 9.06s
# 14:	learn: 18607.0392886	total: 135ms	remaining: 8.89s
# 15:	learn: 18482.4904579	total: 142ms	remaining: 8.74s
# 16:	learn: 18348.3712751	total: 149ms	remaining: 8.61s
# ...

# %%
yp=f.predict(x_test)

# %%
from sklearn.metrics import mean_squared_log_error
np.sqrt(mean_squared_log_error( y_test, yp ))
# Out:
# 0.6101808045811056

# %%
final_df
# Out:
#      Brand  City  Locality  State  gb128  gb16  gb2  gb256  gb3  gb32  gb4  \
# 0        1     8       878      2      0     0    0      0    0     0    1
# 1        1     4      1081      0      0     0    0      0    0     0    0
# 2        1    11       495      4      1     0    0      1    0     0    0
# 3        1    10       287      7      0     0    0      1    0     0    1
# 4        1     4       342      0      0     0    0      0    0     0    1
# ..     ...   ...       ...    ...    ...   ...  ...    ...  ...   ...  ...
# 992      1     4       796      0      0     1    1      0    0     1    0
# 993      1    17       145      7      1     0    0      0    0     0    0
# 994      0    13       352      5      1     0    1      0    1     1    0
# 995      1     4       350      0      0     0    0      0    0     0    0
# 996      1    11       602      4      1     0    0      0    0     0    0
#
#      gb6  gb64  gb8
# 0      0     1    0
# 1      0     0    0
# ...

# %%
yp=f.predict(xt)

# %%
k=pd.DataFrame(yp,columns=["Price"])

# %%
k.to_excel("g3.xlsx",index=False)
